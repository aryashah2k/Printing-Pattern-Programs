# %% [markdown]
# #  Alphabetic Patterns

# %% [markdown]
# ![Pattern%201.jpg](attachment:Pattern%201.jpg)

# %%
for x in range(65, 70):
    for y in range(1, 6):
        print(chr(x), end="")
    print()
# Out:
# AAAAA
# BBBBB
# CCCCC
# DDDDD
# EEEEE

# %%
#Alternative
for x in 'ABCDE':
    for y in 'ABCDE':
        print(x,end="")
    print()
# Out:
# AAAAA
# BBBBB
# CCCCC
# DDDDD
# EEEEE

# %% [markdown]
# ![Pattern%202.jpg](attachment:Pattern%202.jpg)

# %%
for x in range(1, 6):
    for y in range(65, 70):
        print(chr(y), end="")
    print()
# Out:
# ABCDE
# ABCDE
# ABCDE
# ABCDE
# ABCDE

# %%
#Alternative
for x in 'ABCDE':
    for y in 'ABCDE':
        print(y,end="")
    print()
# Out:
# ABCDE
# ABCDE
# ABCDE
# ABCDE
# ABCDE

# %% [markdown]
# ![Pattern%203.jpg](attachment:Pattern%203.jpg)

# %%
for x in range(69, 64, -1):
    for y in range(1, 6):
        print(chr(x), end="")
    print()
# Out:
# EEEEE
# DDDDD
# CCCCC
# BBBBB
# AAAAA

# %%
#Alternative
for x in 'EDCBA':
    for y in 'EDCBA':
        print(x,end="")
    print()
# Out:
# EEEEE
# DDDDD
# CCCCC
# BBBBB
# AAAAA

# %% [markdown]
# ![Pattern%204.jpg](attachment:Pattern%204.jpg)

# %%
for x in range(1, 6):
    for y in range(69, 64, -1):
        print(chr(y), end="")
    print()
# Out:
# EDCBA
# EDCBA
# EDCBA
# EDCBA
# EDCBA

# %%
#Alternative
for x in 'EDCBA':
    for y in 'EDCBA':
        print(y,end="")
    print()
# Out:
# EDCBA
# EDCBA
# EDCBA
# EDCBA
# EDCBA

# %% [markdown]
# ![Pattern%205.jpg](attachment:Pattern%205.jpg)

# %%
for x in range(65, 70):
    for y in range(65, x + 1):
        print(chr(x), end="")
    print()
# Out:
# A
# BB
# CCC
# DDDD
# EEEEE

# %% [markdown]
# ![Pattern%206.jpg](attachment:Pattern%206.jpg)

# %%
for x in range(65, 70):
    for y in range(65, x + 1):
        print(chr(y), end="")
    print()
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE

# %% [markdown]
# ![Pattern%207.jpg](attachment:Pattern%207.jpg)

# %%
for x in range(0, 5):
    for y in range(4, x - 1, -1):
        print(chr(x + 65), end="")
    print()
# Out:
# AAAAA
# BBBB
# CCC
# DD
# E

# %% [markdown]
# ![Pattern%208.jpg](attachment:Pattern%208.jpg)

# %%
for x in range(5, 0, -1):
    for y in range(0, x):
        print(chr(y + 65), end="")
    print()
# Out:
# ABCDE
# ABCD
# ABC
# AB
# A

# %% [markdown]
# ![Pattern%209.jpg](attachment:Pattern%209.jpg)

# %%
for x in range(5, 0, -1):
    for y in range(0, x):
        print(chr(x + 64), end="")
    print()
# Out:
# EEEEE
# DDDD
# CCC
# BB
# A

# %% [markdown]
# ![Pattern%2010.jpg](attachment:Pattern%2010.jpg)

# %%
for x in range(0, 5):
    for y in range(4, x - 1, -1):
        print(chr(y + 65), end="")
    print()
# Out:
# EDCBA
# EDCB
# EDC
# ED
# E

# %% [markdown]
# ![Pattern%2011.jpg](attachment:Pattern%2011.jpg)

# %%
for x in range(1, 6):
    for y in range(5, x, -1):
        print(" ", end="")
    for z in range(0, x):
        print(chr(x + 64), end="")
    print()
# Out:
#     A
#    BB
#   CCC
#  DDDD
# EEEEE

# %% [markdown]
# ![Pattern%2012.jpg](attachment:Pattern%2012.jpg)

# %%
for x in range(1, 6):
    for y in range(5, x, -1):
        print(" ", end="")
    for z in range(1, x + 1):
        print(chr(z + 64), end="")
    print()
# Out:
#     A
#    AB
#   ABC
#  ABCD
# ABCDE

# %% [markdown]
# ![Pattern%2013.jpg](attachment:Pattern%2013.jpg)

# %%
for x in range(5, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(0, x):
        print(chr(x + 64), end="")
    print()
# Out:
# EEEEE
#  DDDD
#   CCC
#    BB
#     A

# %% [markdown]
# ![Pattern%2014.jpg](attachment:Pattern%2014.jpg)

# %%
for x in range(5, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(0, x):
        print(chr(z + 65), end="")
    print()
# Out:
# ABCDE
#  ABCD
#   ABC
#    AB
#     A

# %% [markdown]
# ![Pattern%2015.jpg](attachment:Pattern%2015.jpg)

# %%
inc = 1
char = 65  # ASCII of 'A'
for x in range(5, 0, -1):
    for y in range(x, 0, -1):
        print(" ", end="")
    print(chr(char) * inc, end="")
    char += 1
    inc += 2;
    print()
# Out:
#      A
#     BBB
#    CCCCC
#   DDDDDDD
#  EEEEEEEEE

# %% [markdown]
# ![Pattern%2016.jpg](attachment:Pattern%2016.jpg)

# %%
inc = 1
char = 65  # ASCII of 'A'
for x in range(5, 0, -1):
    for y in range(x, 0, -1):
        print(" ", end="")
    print(chr(char) * inc, end="")
    char += 2
    inc += 2;
    print()
# Out:
#      A
#     CCC
#    EEEEE
#   GGGGGGG
#  IIIIIIIII

# %% [markdown]
# ![Pattern%2017.jpg](attachment:Pattern%2017.jpg)

# %%
inc = 1
for x in range(5, 0, -1):
    for y in range(x, 0, -1):
        print(" ", end="")
    for z in range(1, inc + 1):
        print(chr(z + 64), end="")
    inc += 2;
    print()
# Out:
#      A
#     ABC
#    ABCDE
#   ABCDEFG
#  ABCDEFGHI

# %% [markdown]
# ![Pattern%2018.jpg](attachment:Pattern%2018.jpg)

# %%
inc = 1
for x in range(5, 0, -1):
    for y in range(x, 0, -1):
        print(" ", end="")
    for z in range(inc, 0, -1):
        print(chr(z + 64), end="")
    inc += 2;
    print()
# Out:
#      A
#     CBA
#    EDCBA
#   GFEDCBA
#  IHGFEDCBA

# %% [markdown]
# ![Pattern%2019.jpg](attachment:Pattern%2019.jpg)

# %%
inc = 1
for x in range(1, 6):
    for y in range(5, x, -1):
        print(" ", end="")
    for z in range(1, inc + 1):
        print(chr(abs(z - x) + 65), end="")
    inc += 2;
    print()
# Out:
#     A
#    BAB
#   CBABC
#  DCBABCD
# EDCBABCDE

# %% [markdown]
# ![Pattern%2020.jpg](attachment:Pattern%2020.jpg)

# %%
inc = 1
for x in range(0, 5):
    for y in range(4, x, -1):
        print(" ", end="")
    for z in range(x, -(x + 1), -1):
        print(chr(x - abs(z) + 65), end="")
    print()
# Out:
#     A
#    ABA
#   ABCBA
#  ABCDCBA
# ABCDEDCBA

# %% [markdown]
# ![Pattern%2021.jpg](attachment:Pattern%2021.jpg)

# %%
decr = 7
for x in range(4, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(1, decr + 1):
        print(chr(x + 64), end="")
    decr -= 2
    print()
# Out:
#  DDDDDDD
#   CCCCC
#    BBB
#     A

# %% [markdown]
# ![Pattern%2022.jpg](attachment:Pattern%2022.jpg)

# %%
decr = 7
for x in range(4, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(1, decr + 1):
        print(chr(decr + 64), end="")
    decr -= 2
    print()
# Out:
#  GGGGGGG
#   EEEEE
#    CCC
#     A

# %% [markdown]
# ![Pattern%2023.jpg](attachment:Pattern%2023.jpg)

# %%
decr = 7
for x in range(4, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(1, decr + 1):
        print(chr(z + 64), end="")
    decr -= 2
    print()
# Out:
#  ABCDEFG
#   ABCDE
#    ABC
#     A

# %% [markdown]
# ![Pattern%2024.jpg](attachment:Pattern%2024.jpg)

# %%
size = 3
for x in range(size, -(size + 1), -1):
    for y in range(size, abs(x) - 1, -1):
        print(chr(y + 65), end=" ")
    print()
# Out:
# D
# D C
# D C B
# D C B A
# D C B
# D C
# D

# %% [markdown]
# ![Pattern%2025.jpg](attachment:Pattern%2025.jpg)

# %%
size = 3
for x in range(size, -(size + 1), -1):
    for y in range(abs(x), size + 1):
        print(chr(y + 65), end=" ")
    print()
# Out:
# D
# C D
# B C D
# A B C D
# B C D
# C D
# D

# %% [markdown]
# ![Pattern%2026.jpg](attachment:Pattern%2026.jpg)

# %%
size = 3
for x in range(size, -(size + 1), -1):
    for y in range(abs(x), 0, -1):
        print(" ", end=" ")
    for z in range(abs(x), 4):
        print(chr(z + 65), end=" ")
    print()
# Out:
#       D
#     C D
#   B C D
# A B C D
#   B C D
#     C D
#       D

# %% [markdown]
# ![Pattern%2027.jpg](attachment:Pattern%2027.jpg)

# %%
size = 3
for x in range(size, -(size + 1), -1):
    for y in range(abs(x), 0, -1):
        print(" ", end=" ")
    for z in range(size, abs(x) - 1, -1):
        print(chr(z + 65), end=" ")
    print()
# Out:
#       D
#     D C
#   D C B
# D C B A
#   D C B
#     D C
#       D

# %% [markdown]
# ![Pattern%2028.jpg](attachment:Pattern%2028.jpg)

# %%
for x in range(1, 6):
    for y in range(5, x, -1):
        print(" ", end="")
    for z in range(0, x):
        print(chr(x + 64) + " ", end="")
    print()
# Out:
#     A
#    B B
#   C C C
#  D D D D
# E E E E E

# %% [markdown]
# ![Pattern%2029.jpg](attachment:Pattern%2029.jpg)

# %%
for x in range(1, 6):
    for y in range(5, x, -1):
        print(" ", end="")
    for z in range(1, x + 1):
        print(chr(z + 64) + " ", end="")
    print()
# Out:
#     A
#    A B
#   A B C
#  A B C D
# A B C D E

# %% [markdown]
# ![Pattern%2030.jpg](attachment:Pattern%2030.jpg)

# %%
for x in range(5, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(0, x):
        print(chr(x + 64) + " ", end="")
    print()
# Out:
# E E E E E
#  D D D D
#   C C C
#    B B
#     A

# %% [markdown]
# ![Pattern%2031.jpg](attachment:Pattern%2031.jpg)

# %%
for x in range(5, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(x, 0, -1):
        print(chr(z + 64) + " ", end="")
    print()
# Out:
# E D C B A
#  D C B A
#   C B A
#    B A
#     A

# %% [markdown]
# ![Pattern%2032.jpg](attachment:Pattern%2032.jpg)

# %%
for x in range(5, 0, -1):
    for y in range(x, 5):
        print(" ", end="")
    for z in range(0, x):
        print(chr(z + 65) + " ", end="")
    print()
# Out:
# A B C D E
#  A B C D
#   A B C
#    A B
#     A

# %% [markdown]
# ![Pattern%2033.jpg](attachment:Pattern%2033.jpg)

# %%
size = 4
p = 0
for x in range(size, -(size + 1), -1):
    for y in range(1, abs(x) + 1):
        print(" ", end="")
    for z in range(size, abs(x) - 1, -1):
        print(chr(p + 65) + " ", end="")
    if (x > 0):
        p += 1
    else:
        p -= 1
    print()
# Out:
#     A
#    B B
#   C C C
#  D D D D
# E E E E E
#  D D D D
#   C C C
#    B B
#     A

# %% [markdown]
# ![Pattern%2034.jpg](attachment:Pattern%2034.jpg)

# %%
size = 4
p = 0
for x in range(size, -(size + 1), -1):
    for y in range(1, abs(x) + 1):
        print(" ", end="")

    if (x >= 0):
        p = 0
    else:
        p = y

    for z in range(size, abs(x) - 1, -1):
        print(chr(p + 65) + " ", end="")
        p += 1
    print()
# Out:
#     A
#    A B
#   A B C
#  A B C D
# A B C D E
#  B C D E
#   C D E
#    D E
#     E

# %% [markdown]
# ![Pattern%2035.jpg](attachment:Pattern%2035.jpg)

# %%
n = 5  # size=5
px = n
py = n
for x in range(1, n + 1):
    for y in range(1, n * 2 + 1):
        if (y == px or y == py):
            print(chr(x + 64), end="")  # 1
        else:
            print(" ", end="")
    px -= 1
    py += 1
    print()

    """
    1+64>> 65 >> ASCII of 'A'
    
    """
# Out:
#     A
#    B B
#   C   C
#  D     D
# E       E

# %% [markdown]
# ![Pattern%2036.jpg](attachment:Pattern%2036.jpg)

# %%
n = 5  # size=5
px = n
py = n
for x in range(1, n + 1):
    for y in range(1, n * 2 + 1):
        if (y == px or y == py):
            print(chr(px + 64), end="")  # 1
        else:
            print(" ", end="")
    px -= 1
    py += 1
    print()

    """
    5+64>> 69 >> ASCII of 'E'
    
    """
# Out:
#     E
#    D D
#   C   C
#  B     B
# A       A

# %% [markdown]
# ![Pattern%2037.jpg](attachment:Pattern%2037.jpg)

# %%
n = 5  # size=5
px = 1
py = n * 2 - 1
for x in range(1, n + 1):
    for y in range(1, n * 2 + 1):
        if (y == px or y == py):
            print(chr(x + 64), end="")  # 1
        else:
            print(" ", end="")
    px += 1
    py -= 1
    print()

    """
    1+64>> 65 >> ASCII of 'A'
    """
# Out:
# A       A
#  B     B
#   C   C
#    D D
#     E

# %% [markdown]
# ![Pattern%2038.jpg](attachment:Pattern%2038.jpg)

# %%
n = 5  # size=5
px = 1
py = n * 2 - 1
for x in range(n, 0, -1):
    for y in range(1, n * 2 + 1):
        if (y == px or y == py):
            print(chr(x + 64), end="")
        else:
            print(" ", end="")
    px += 1
    py -= 1
    print()

    """
    5+64>> 69 >> ASCII of 'E'
    """
# Out:
# E       E
#  D     D
#   C   C
#    B B
#     A

# %% [markdown]
# ![Pattern%2039.jpg](attachment:Pattern%2039.jpg)

# %%
n = 9  # size
px = n // 2 + 1
p = 0  # print val
for x in range(1, n + 1):
    for y in range(1, n + 1):
        if (y == px or y == n - px + 1):
            print(chr(p + 65), end="")
        else:
            print(" ", end="")
    if (x <= n / 2):
        px -= 1
        p += 1
    else:
        px += 1
        p -= 1
    print()
# Out:
#     A
#    B B
#   C   C
#  D     D
# E       E
#  D     D
#   C   C
#    B B
#     A

# %% [markdown]
# ![Pattern%2040.jpg](attachment:Pattern%2040.jpg)

# %%
n = 9  # size
px = n // 2 + 1
for x in range(1, n + 1):
    for y in range(1, n + 1):
        if (y == px or y == n - px + 1):
            print(chr(px + 64), end="")  # 1
        else:
            print(" ", end="")
    if (x <= n / 2):
        px -= 1
    else:
        px += 1
    print()

    """
     5+64>> 69 >> ASCII of 'E'
    """
# Out:
#     E
#    D D
#   C   C
#  B     B
# A       A
#  B     B
#   C   C
#    D D
#     E

# %% [markdown]
# ![Pattern%2041.jpg](attachment:Pattern%2041.jpg)

# %%
n = 5  # size
for x in range(0, n):
    for y in range(0, n):
        if (x == y or x + y == n - 1):
            print(chr(x + 65), end="")
        else:
            print(" ", end="")
    print()
# Out:
# A   A
#  B B
#   C
#  D D
# E   E

# %% [markdown]
# ![Pattern%2042.jpg](attachment:Pattern%2042.jpg)

# %%
n = 5  # size
for x in range(0, n):
    for y in range(0, n):
        if (x == y or x + y == n - 1):
            print(chr(y + 65), end="")
        else:
            print(" ", end="")
    print()
# Out:
# A   E
#  B D
#   C
#  B D
# A   E

# %% [markdown]
# ![Pattern%2043.jpg](attachment:Pattern%2043.jpg)

# %%
string = "PythonPattern"
strlen = len(string)
for x in range(0, strlen):
    print(string[0:x + 1])
for y in range(0, strlen):
    print(string[0:strlen - y])
# Out:
# P
# Py
# Pyt
# Pyth
# Pytho
# Python
# PythonP
# PythonPa
# PythonPat
# PythonPatt
# PythonPatte
# PythonPatter
# PythonPattern
# PythonPattern
# PythonPatter
# PythonPatte
# PythonPatt
# PythonPat
# PythonPa
# PythonP
# Python
# Pytho
# Pyth
# Pyt
# Py
# P

# %% [markdown]
# ![Pattern%2044.jpg](attachment:Pattern%2044.jpg)

# %%
n = 4  # size
p = 1  # for printing
q = (n * n) + 1

for x in range(n, 0, -1):
    for y in range(1, x + 1):
        print(str(q) + " ", end="")
        q += 1
    q -= 1
    q = q - ((x - 1) * 2)
    print()
# Out:
# 17 18 19 20
# 14 15 16
# 12 13
# 11

# %% [markdown]
# ![Pattern%2045.jpg](attachment:Pattern%2045.jpg)

# %%
p_height = 5  # size
p_space = p_height - 1
m = 1
np = 1  # for num printing
cp = 'A'  # for char printing

for x in range(1, p_height + 1):
    for y in range(p_space, x - 1, -1):
        print(" ", end="")
    for z in range(1, m + 1):
        if (x % 2 != 0):
            print(np, end="")  # 1
            np += 1
        else:
            print(cp, end="")  # 2
            cp = chr(ord(cp) + 1)  # 3
        np = 1 if (np > 9) else np  # 4
        cp = 'A' if (cp > 'Z') else cp  # 5
    m += 2
    print()

    """
1) Print numbers if row is Odd
2) Print characters if row is Even
3) Incrementing the character
4) Reset number
5) Reset character
    """
# Out:
#     1
#    ABC
#   23456
#  DEFGHIJ
# 789123456

# %% [markdown]
# ![Pattern%2046.jpg](attachment:Pattern%2046.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
# A
# 22
# CCC
# 4444
# EEEEE

# %% [markdown]
# ![Pattern%2047.jpg](attachment:Pattern%2047.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
# A
# 12
# ABC
# 1234
# ABCDE

# %% [markdown]
# ![Pattern%2048.jpg](attachment:Pattern%2048.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
# 1
# BB
# 333
# DDDD
# 55555

# %% [markdown]
# ![Pattern%2049.jpg](attachment:Pattern%2049.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
# 1
# AB
# 123
# ABCD
# 12345

# %% [markdown]
# ![Pattern%2050.jpg](attachment:Pattern%2050.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
# EEEEE
# 4444
# CCC
# 22
# A

# %% [markdown]
# ![Pattern%2051.jpg](attachment:Pattern%2051.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
# ABCDE
# 1234
# ABC
# 12
# A

# %% [markdown]
# ![Pattern%2052.jpg](attachment:Pattern%2052.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
# 55555
# DDDD
# 333
# BB
# 1

# %% [markdown]
# ![Pattern%2053.jpg](attachment:Pattern%2053.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
# 12345
# ABCD
# 123
# AB
# 1

# %% [markdown]
# ![Pattern%2054.jpg](attachment:Pattern%2054.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
#     A
#    22
#   CCC
#  4444
# EEEEE

# %% [markdown]
# ![Pattern%2055.jpg](attachment:Pattern%2055.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
#     A
#    12
#   ABC
#  1234
# ABCDE

# %% [markdown]
# ![Pattern%2056.jpg](attachment:Pattern%2056.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
#     1
#    BB
#   333
#  DDDD
# 55555

# %% [markdown]
# ![Pattern%2057.jpg](attachment:Pattern%2057.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
#     1
#    AB
#   123
#  ABCD
# 12345

# %% [markdown]
# ![Pattern%2058.jpg](attachment:Pattern%2058.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
# EEEEE
#  4444
#   CCC
#    22
#     A

# %% [markdown]
# ![Pattern%2059.jpg](attachment:Pattern%2059.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
# ABCDE
#  1234
#   ABC
#    12
#     A

# %% [markdown]
# ![Pattern%2060.jpg](attachment:Pattern%2060.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(x + 64), end="")  # for char
        else:
            print(x, end="")
    print()
# Out:
# 55555
#  DDDD
#   333
#    BB
#     1

# %% [markdown]
# ![Pattern%2061.jpg](attachment:Pattern%2061.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(y + 64), end="")  # for char
        else:
            print(y, end="")
    print()
# Out:
# 12345
#  ABCD
#   123
#    AB
#     1

# %% [markdown]
# ![Pattern%2062.jpg](attachment:Pattern%2062.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(x + 64) + " ", end="")  # for char
        else:
            print(str(x) + " ", end="")
    print()
# Out:
#     A
#    2 2
#   C C C
#  4 4 4 4
# E E E E E

# %% [markdown]
# ![Pattern%2063.jpg](attachment:Pattern%2063.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(x + 64) + " ", end="")  # for char
        else:
            print(str(y) + " ", end="")
    print()
# Out:
#     A
#    1 2
#   C C C
#  1 2 3 4
# E E E E E

# %% [markdown]
# ![Pattern%2064.jpg](attachment:Pattern%2064.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(x + 64) + " ", end="")  # for char
        else:
            print(str(x) + " ", end="")
    print()
# Out:
#     1
#    B B
#   3 3 3
#  D D D D
# 5 5 5 5 5

# %% [markdown]
# ![Pattern%2065.jpg](attachment:Pattern%2065.jpg)

# %%
n = 5  # size
for x in range(1, n + 1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(y + 64) + " ", end="")  # for char
        else:
            print(str(y) + " ", end="")
    print()
# Out:
#     1
#    A B
#   1 2 3
#  A B C D
# 1 2 3 4 5

# %% [markdown]
# ![Pattern%2066.jpg](attachment:Pattern%2066.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(x + 64) + " ", end="")  # for char
        else:
            print(str(x) + " ", end="")
    print()
# Out:
# E E E E E
#  4 4 4 4
#   C C C
#    2 2
#     A

# %% [markdown]
# ![Pattern%2067.jpg](attachment:Pattern%2067.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 != 0):
            print(chr(y + 64) + " ", end="")  # for char
        else:
            print(str(y) + " ", end="")
    print()
# Out:
# A B C D E
#  1 2 3 4
#   A B C
#    1 2
#     A

# %% [markdown]
# ![Pattern%2068.jpg](attachment:Pattern%2068.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(x + 64) + " ", end="")  # for char
        else:
            print(str(x) + " ", end="")
    print()
# Out:
# 5 5 5 5 5
#  D D D D
#   3 3 3
#    B B
#     1

# %% [markdown]
# ![Pattern%2069.jpg](attachment:Pattern%2069.jpg)

# %%
n = 5  # size
for x in range(n, 0, -1):
    for s in range(n - 1, x - 1, -1):
        print(" ", end="")
    for y in range(1, x + 1):
        if (x % 2 == 0):
            print(chr(y + 64) + " ", end="")  # for char
        else:
            print(str(y) + " ", end="")
    print()
# Out:
# 1 2 3 4 5
#  A B C D
#   1 2 3
#    A B
#     1

# %% [markdown]
# ![Pattern%2070.jpg](attachment:Pattern%2070.jpg)

# %%
n = 5
for x in range(0, n):
    for y in range(0, n):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(x+65), end=" ")
    print()

    """
65 > ASCII of 'A'
    """
# Out:
# A * * * *
# B B * * *
# C C C * *
# D D D D *
# E E E E E

# %% [markdown]
# ![Pattern%2071.jpg](attachment:Pattern%2071.jpg)

# %%
n = 5
for x in range(0, n):
    for y in range(0, n):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(y+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# A * * * *
# A B * * *
# A B C * *
# A B C D *
# A B C D E
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2072.jpg](attachment:Pattern%2072.jpg)

# %%
n = 4
for x in range(n, -1, -1):
    for y in range(0, n+1):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(x+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# E E E E E
# D D D D *
# C C C * *
# B B * * *
# A * * * *
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2073.jpg](attachment:Pattern%2073.jpg)

# %%
n = 4
for x in range(n, -1, -1):
    for y in range(0, n+1):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(y+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# A B C D E
# A B C D *
# A B C * *
# A B * * *
# A * * * *
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2074.jpg](attachment:Pattern%2074.jpg)

# %%
n = 4
for x in range(0, n+1):
    for y in range(n, -1, -1):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(x+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# * * * * A
# * * * B B
# * * C C C
# * D D D D
# E E E E E
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2075.jpg](attachment:Pattern%2075.jpg)

# %%
n = 4
for x in range(0, n+1):
    for y in range(n, -1, -1):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(y+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# * * * * A
# * * * B A
# * * C B A
# * D C B A
# E D C B A
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2076.jpg](attachment:Pattern%2076.jpg)

# %%
n = 4
for x in range(n, -1, -1):
    for y in range(n, -1, -1):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(x+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# E E E E E
# * D D D D
# * * C C C
# * * * B B
# * * * * A
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2077.jpg](attachment:Pattern%2077.jpg)

# %%
n = 4
for x in range(n, -1, -1):
    for y in range(n, -1, -1):
      if y > x:
        print("*", end=" ")
      else:
        print(chr(y+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# E D C B A
# * D C B A
# * * C B A
# * * * B A
# * * * * A
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2078.jpg](attachment:Pattern%2078.jpg)

# %%
for x in 'ABCDE':
 for y in 'ABCDE':
   if y < x:
      print(y, end=" ")
   else:
      print(x, end=" ")
 print()
# Out:
# A A A A A
# A B B B B
# A B C C C
# A B C D D
# A B C D E

# %%
#Another way

for x in range(65, 70):
    for y in range(65, 70):
      if y < x:
       print(chr(y), end=" ")
      else:
       print(chr(x), end=" ")
    print()
# Out:
# A A A A A
# A B B B B
# A B C C C
# A B C D D
# A B C D E

# %% [markdown]
# ![Pattern%2079.jpg](attachment:Pattern%2079.jpg)

# %%
for x in 'EDCBA':
 for y in 'ABCDE':
   if y < x:
      print(y, end=" ")
   else:
      print(x, end=" ")
 print()
# Out:
# A B C D E
# A B C D D
# A B C C C
# A B B B B
# A A A A A

# %%
#Another way

for x in range(69, 64, -1):
    for y in range(65, 70):
      if y < x:
       print(chr(y), end=" ")
      else:
       print(chr(x), end=" ")
    print()
# Out:
# A B C D E
# A B C D D
# A B C C C
# A B B B B
# A A A A A

# %% [markdown]
# ![Pattern%2080.jpg](attachment:Pattern%2080.jpg)

# %%
for x in 'ABCDE':
 for y in 'ABCDE':
   if y < x: 
      print(x, end=" ")
   else:
      print(y, end=" ")
 print()
# Out:
# A B C D E
# B B C D E
# C C C D E
# D D D D E
# E E E E E

# %%
#Another way

for x in range(65, 70):
    for y in range(65, 70):
      if y < x:
       print(chr(x), end=" ")
      else:
       print(chr(y), end=" ")
    print()
# Out:
# A B C D E
# B B C D E
# C C C D E
# D D D D E
# E E E E E

# %% [markdown]
# ![Pattern%2081.jpg](attachment:Pattern%2081.jpg)

# %%
for x in 'EDCBA':
 for y in 'ABCDE':
   if y < x:
      print(x, end=" ")
   else:
      print(y, end=" ")
 print()
# Out:
# E E E E E
# D D D D E
# C C C D E
# B B C D E
# A B C D E

# %%
#Another way

for x in range(69, 64, -1):
    for y in range(65, 70):
      if y < x:
       print(chr(x), end=" ")
      else:
       print(chr(y), end=" ")
    print()
# Out:
# E E E E E
# D D D D E
# C C C D E
# B B C D E
# A B C D E

# %% [markdown]
# ![Pattern%2082.jpg](attachment:Pattern%2082.jpg)

# %%
for x in range(0, 4):
    for y in range(x, x+4):
      print(chr((y%4)+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# A B C D
# B C D A
# C D A B
# D A B C
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2083.jpg](attachment:Pattern%2083.jpg)

# %%
size=4
for x in range(size, -size-1, -1):
    for y in range(0, abs(x)+1):
      print(chr(y+65), end=" ")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# A B C D E
# A B C D
# A B C
# A B
# A
# A B
# A B C
# A B C D
# A B C D E
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2084.jpg](attachment:Pattern%2084.jpg)

# %%
size=4
for x in range(size, -size-1, -1):
    for y in range(abs(x), -1, -1):
      print(chr(y+65), end="")
    print()

"""
65 > ASCII of 'A'
"""
# Out:
# EDCBA
# DCBA
# CBA
# BA
# A
# BA
# CBA
# DCBA
# EDCBA
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2085.jpg](attachment:Pattern%2085.jpg)

# %%
n=5
for x in range(0, n):
  for y in range(0, x+1):
    for z in range(0, y + 1):
      print(chr(x+65), end="")
    print()
  print()

"""
65 > ASCII of 'A'
"""
# Out:
# A
#
# B
# BB
#
# C
# CC
# CCC
#
# D
# DD
# DDD
# DDDD
#
# E
# EE
# EEE
# EEEE
# EEEEE
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2086.jpg](attachment:Pattern%2086.jpg)

# %%
n=5
for x in range(0, n):
  for y in range(0, x+1):
    for z in range(0, y + 1):
      print(chr(y+65), end="")
    print()
  print()

"""
65 > ASCII of 'A'
"""
# Out:
# A
#
# A
# BB
#
# A
# BB
# CCC
#
# A
# BB
# CCC
# DDDD
#
# A
# BB
# CCC
# DDDD
# EEEEE
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2087.jpg](attachment:Pattern%2087.jpg)

# %%
n=5
for x in range(0, n):
  for y in range(0, x+1):
    for z in range(0, y + 1):
      print(chr(z+65), end="")
    print()
  print()

"""
65 > ASCII of 'A'
"""
# Out:
# A
#
# A
# AB
#
# A
# AB
# ABC
#
# A
# AB
# ABC
# ABCD
#
# A
# AB
# ABC
# ABCD
# ABCDE
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2088.jpg](attachment:Pattern%2088.jpg)

# %%
n=4 #size
pc=0
for x in range(1, n+1):
  for y in range(n-1, x-1, -1):
    print(" ", end=" ")
  for z in range(x-1,-x, -1):
    print(chr(pc-abs(z)+65), end=" ")
  pc+=2
  print()

"""
65 > ASCII of 'A'
"""
# Out:
#       A
#     B C B
#   C D E D C
# D E F G F E D
# "\n65 > ASCII of 'A'\n"

# %% [markdown]
# ![Pattern%2089.jpg](attachment:Pattern%2089.jpg)

# %%
string = "PATTERN"
strlen = len(string)

for x in range(0, strlen):
  print(string[0:x+1])
# Out:
# P
# PA
# PAT
# PATT
# PATTE
# PATTER
# PATTERN

# %% [markdown]
# ![Pattern%2090.jpg](attachment:Pattern%2090.jpg)

# %%
string = "PATTERN"
strlen = len(string)

for x in range(0, strlen):
  print(string[0:strlen-x])
# Out:
# PATTERN
# PATTER
# PATTE
# PATT
# PAT
# PA
# P

# %% [markdown]
# ![Pattern%2091.jpg](attachment:Pattern%2091.jpg)

# %%
string = "ABCDE"

for x in range(0, 5):
 for y in range(0, 5):
  if x == 2:
   print(string[y],end=" ")
  elif y == 2:
   print(string[x],end=" ")
  else:
   print(" ",end=" ")
 print("")
# Out:
#     A
#     B
# A B C D E
#     D
#     E
